# %%
import gym
env = gym.make('Copy-v0')
env.reset()
env.render()
# Out:
# [2017-10-16 12:00:58,391] Making new env: Copy-v0
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   CBCB
# Output Tape         :
# Targets             :   CBCB

# %%
import gym
env = gym.make('Copy-v0')

# Run few episodes.
for ep in range(5):
    # Start new episode
    print("! New episode !")
    # Start new episode and get initial state.
    obs = env.reset()
    env.render()

    # Pefson n steps until the end of sequence.
    for step in range(10):
        print("Executing ",str(step),"-th action")
        # Next action: move right, write to what has been reed to output.
        act= (1, 1, obs)
        print("act=",act)
        # Environment returns observation, reward, and boolean flag indicating if the episode is complete.
        obs,rew,done,_ = env.step(act) 
        print("step=",step)
        print("obs=",obs)
        #print("rew=",rew)
        print("done=",done)
        env.render()
        if done == True:
            break
# Out:
# [2017-10-16 13:26:59,024] Making new env: Copy-v0
# ! New episode !
# 4
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :
# Targets             :   EABB
#
#
#
#
#
#
# Execute initial read action
# act= (1, 0, 0)
# obs= 0
# Total length of input instance: 4, step: 1
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :
# Targets             :   EABB
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: False,
#                               prediction: A)
# Move head back!
# act= (0, 0, 0)
# obs= 4
# Total length of input instance: 4, step: 2
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :
# Targets             :   EABB
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: left,
#                               write to the output tape: False,
#                               prediction: A)
# Executing  0 -th action
# act= (1, 1, 4)
# step= 0
# obs= 0
# done= False
# Total length of input instance: 4, step: 3
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :   E
# Targets             :   EABB
#
# Current reward      :   1.000
# Cumulative reward   :   1.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  1 -th action
# act= (1, 1, 0)
# step= 1
# obs= 1
# done= False
# Total length of input instance: 4, step: 4
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :   EA
# Targets             :   EABB
#
# Current reward      :   1.000
# Cumulative reward   :   2.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: A)
# Executing  2 -th action
# act= (1, 1, 1)
# step= 2
# obs= 1
# done= False
# Total length of input instance: 4, step: 5
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :   EAB
# Targets             :   EABB
#
# Current reward      :   1.000
# Cumulative reward   :   3.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# Executing  3 -th action
# act= (1, 1, 1)
# step= 3
# obs= 5
# done= True
# Total length of input instance: 4, step: 6
# ==========================================
# Observation Tape    :   EABB
# Output Tape         :   EABB
# Targets             :   EABB
#
# Current reward      :   1.000
# Cumulative reward   :   4.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# ! New episode !
# 4
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :
# Targets             :   ECEE
#
#
#
#
#
#
# Execute initial read action
# act= (1, 0, 0)
# obs= 2
# Total length of input instance: 4, step: 1
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :
# Targets             :   ECEE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: False,
#                               prediction: A)
# Move head back!
# act= (0, 0, 0)
# obs= 4
# Total length of input instance: 4, step: 2
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :
# Targets             :   ECEE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: left,
#                               write to the output tape: False,
#                               prediction: A)
# Executing  0 -th action
# act= (1, 1, 4)
# step= 0
# obs= 2
# done= False
# Total length of input instance: 4, step: 3
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :   E
# Targets             :   ECEE
#
# Current reward      :   1.000
# Cumulative reward   :   1.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  1 -th action
# act= (1, 1, 2)
# step= 1
# obs= 4
# done= False
# Total length of input instance: 4, step: 4
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :   EC
# Targets             :   ECEE
#
# Current reward      :   1.000
# Cumulative reward   :   2.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: C)
# Executing  2 -th action
# act= (1, 1, 4)
# step= 2
# obs= 4
# done= False
# Total length of input instance: 4, step: 5
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :   ECE
# Targets             :   ECEE
#
# Current reward      :   1.000
# Cumulative reward   :   3.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  3 -th action
# act= (1, 1, 4)
# step= 3
# obs= 5
# done= True
# Total length of input instance: 4, step: 6
# ==========================================
# Observation Tape    :   ECEE
# Output Tape         :   ECEE
# Targets             :   ECEE
#
# Current reward      :   1.000
# Cumulative reward   :   4.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# ! New episode !
# 1
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :
# Targets             :   BEEE
#
#
#
#
#
#
# Execute initial read action
# act= (1, 0, 0)
# obs= 4
# Total length of input instance: 4, step: 1
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :
# Targets             :   BEEE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: False,
#                               prediction: A)
# Move head back!
# act= (0, 0, 0)
# obs= 1
# Total length of input instance: 4, step: 2
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :
# Targets             :   BEEE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: left,
#                               write to the output tape: False,
#                               prediction: A)
# Executing  0 -th action
# act= (1, 1, 1)
# step= 0
# obs= 4
# done= False
# Total length of input instance: 4, step: 3
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :   B
# Targets             :   BEEE
#
# Current reward      :   1.000
# Cumulative reward   :   1.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# Executing  1 -th action
# act= (1, 1, 4)
# step= 1
# obs= 4
# done= False
# Total length of input instance: 4, step: 4
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :   BE
# Targets             :   BEEE
#
# Current reward      :   1.000
# Cumulative reward   :   2.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  2 -th action
# act= (1, 1, 4)
# step= 2
# obs= 4
# done= False
# Total length of input instance: 4, step: 5
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :   BEE
# Targets             :   BEEE
#
# Current reward      :   1.000
# Cumulative reward   :   3.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  3 -th action
# act= (1, 1, 4)
# step= 3
# obs= 5
# done= True
# Total length of input instance: 4, step: 6
# ==========================================
# Observation Tape    :   BEEE
# Output Tape         :   BEEE
# Targets             :   BEEE
#
# Current reward      :   1.000
# Cumulative reward   :   4.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# ! New episode !
# 1
# Total length of input instance: 3, step: 0
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :
# Targets             :   BBE
#
#
#
#
#
#
# Execute initial read action
# act= (1, 0, 0)
# obs= 1
# Total length of input instance: 3, step: 1
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :
# Targets             :   BBE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: False,
#                               prediction: A)
# Move head back!
# act= (0, 0, 0)
# obs= 1
# Total length of input instance: 3, step: 2
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :
# Targets             :   BBE
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: left,
#                               write to the output tape: False,
#                               prediction: A)
# Executing  0 -th action
# act= (1, 1, 1)
# step= 0
# obs= 1
# done= False
# Total length of input instance: 3, step: 3
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :   B
# Targets             :   BBE
#
# Current reward      :   1.000
# Cumulative reward   :   1.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# Executing  1 -th action
# act= (1, 1, 1)
# step= 1
# obs= 4
# done= False
# Total length of input instance: 3, step: 4
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :   BB
# Targets             :   BBE
#
# Current reward      :   1.000
# Cumulative reward   :   2.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# Executing  2 -th action
# act= (1, 1, 4)
# step= 2
# obs= 5
# done= True
# Total length of input instance: 3, step: 5
# ==========================================
# Observation Tape    :   BBE
# Output Tape         :   BBE
# Targets             :   BBE
#
# Current reward      :   1.000
# Cumulative reward   :   3.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# ! New episode !
# 1
# Total length of input instance: 4, step: 0
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :
# Targets             :   BAED
#
#
#
#
#
#
# Execute initial read action
# act= (1, 0, 0)
# obs= 0
# Total length of input instance: 4, step: 1
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :
# Targets             :   BAED
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: False,
#                               prediction: A)
# Move head back!
# act= (0, 0, 0)
# obs= 1
# Total length of input instance: 4, step: 2
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :
# Targets             :   BAED
#
# Current reward      :   0.000
# Cumulative reward   :   0.000
# Action              :   Tuple(move over input: left,
#                               write to the output tape: False,
#                               prediction: A)
# Executing  0 -th action
# act= (1, 1, 1)
# step= 0
# obs= 0
# done= False
# Total length of input instance: 4, step: 3
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :   B
# Targets             :   BAED
#
# Current reward      :   1.000
# Cumulative reward   :   1.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: B)
# Executing  1 -th action
# act= (1, 1, 0)
# step= 1
# obs= 4
# done= False
# Total length of input instance: 4, step: 4
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :   BA
# Targets             :   BAED
#
# Current reward      :   1.000
# Cumulative reward   :   2.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: A)
# Executing  2 -th action
# act= (1, 1, 4)
# step= 2
# obs= 3
# done= False
# Total length of input instance: 4, step: 5
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :   BAE
# Targets             :   BAED
#
# Current reward      :   1.000
# Cumulative reward   :   3.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: E)
# Executing  3 -th action
# act= (1, 1, 3)
# step= 3
# obs= 5
# done= True
# Total length of input instance: 4, step: 6
# ==========================================
# Observation Tape    :   BAED
# Output Tape         :   BAED
# Targets             :   BAED
#
# Current reward      :   1.000
# Cumulative reward   :   4.000
# Action              :   Tuple(move over input: right,
#                               write to the output tape: True,
#                               prediction: D)
