# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load csv file
df = pd.read_csv('data/outfit.csv')
#df

# %% [markdown]
# ### Body type

# %%
# Simple "body(_type)" plot
df["body"].value_counts().plot.pie()
plt.show()

# BODY_TYPE = [1, 2, 3, 4]

# %% [markdown]
# ### Style

# %%
# Simple "style" plot
df["style"].value_counts().plot.pie()
plt.show()

#WEATHER = {
#    1: "Freezing",
#    2: "Cold",
#    3: "Chilly",
#    4: "Fresh",
#    5: "Warm",
#    6: "Hot",
#    7: "Wind",
#    8: "Rain",
#    9: "Snow"
#}

# %% [markdown]
# ### Weather

# %%
# Simple "style" plot
df["weather"].value_counts().plot.pie()
plt.show()

#STYLE = {
#    1: "Casual",
#    2: "Grunge",
#    3: "Business",
#    4: "Glam",
#    5: "Boho",
#    6: "Artsy",
#    7: "Smart Casual"
#}

# %% [markdown]
# ### Pieces

# %%
# Simple "pieces" plot
df["pieces"].value_counts().plot.pie()
plt.show()
